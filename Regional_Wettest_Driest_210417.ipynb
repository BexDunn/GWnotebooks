# %% [markdown]
# This code takes a shapefile of areas with common driest years.
#
# -It loops through the polygons in the shapefile and calculates 5th and 95th percentile in rainfall from the BoM rainfall data, and returns the years which are over/under those margins.
#
# -for each shapefile it will add the wet and dry years to the polygon attribute table

# %%
# Import the libraries we need in the code and tell matplotlib to display the plots here
# %matplotlib inline
import fiona
import geopandas as gpd
import datacube
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
#import scipy.stats
import pandas
#import csv
import os

#libraries for polygon and polygon mask
import fiona
import shapely.geometry
import rasterio.features
import rasterio
from datacube.utils import geometry
from datacube.storage.masking import mask_valid_data as mask_invalid_data

import pickle
import logging
from datacube.utils import geometry
from datacube.storage.masking import mask_valid_data as mask_invalid_data

#python logging 
logging.getLogger('datacube.storage.storage').setLevel(logging.ERROR)
dc = datacube.Datacube(app='dc-BOMrainfall')

# %%
#mask to use with our polygons to calculate wet and dry years 
#(comes from http://agdc-v2.readthedocs.io/en/stable/user/guide.html#code-recipes)
def geometry_mask(geoms, geobox, all_touched=False, invert=False):
    """
    Create a mask from shapes.

    By default, mask is intended for use as a
    numpy mask, where pixels that overlap shapes are False.
    :param list[Geometry] geoms: geometries to be rasterized
    :param datacube.utils.GeoBox geobox:
    :param bool all_touched: If True, all pixels touched by geometries will be burned in. If
                             false, only pixels whose center is within the polygon or that
                             are selected by Bresenham's line algorithm will be burned in.
    :param bool invert: If True, mask will be True for pixels that overlap shapes.
    """
    return rasterio.features.geometry_mask([geom.to_crs(geobox.crs) for geom in geoms],
                                           out_shape=geobox.shape,
                                           transform=geobox.affine,
                                           all_touched=all_touched,
                                           invert=invert)

# %%
#Use geopandas to read in the attribute table as a geodataframe

# %%
big_poly = gpd.read_file('/g/data/r78/rjd547/tmp/burdekin_polygons_0_5_deg.shp')

# %%
big_poly.plot()
plt.show()

# %%
#create an empty column
big_poly['WY1'] = None
big_poly['WY2'] = None
big_poly['DY1'] = None
big_poly['DY2'] = None

# %%
# #pick a shape file
shape_file = '/g/data/r78/rjd547/tmp/burdekin_polygons_0_5_deg.shp'
# open all the shapes within the shape file
shapes = fiona.open(shape_file)
for i in range(len(shapes)): 
    geom_crs = geometry.CRS(shapes.crs_wkt)
    geo = shapes[i]['geometry']
    geom = geometry.Geometry(geo, crs=geom_crs)
    geom_bs = shapely.geometry.shape(shapes[i]['geometry'])
    shape_name = shape_file.split('/')[-1].split('.')[0]+'_'+str(i)
    #print(shapes[i]['properties']['DN'], shapes[0]['properties']['Id'])
    #print (geom_bs)

    query = {
           'time': ('1987-01-01','2017-01-01'),
    #          'x': (geom.bounds[0], geom.bounds[2]),
    #          'y': (geom.bounds[1], geom.bounds[3]),
           'geopolygon': geom
    #         'crs': geom_crs,
        }
     #setup rain directory for our pickle data
    rainpath ='/g/data/r78/rjd547/groundwater_activities/Rain/'+shape_name+'/'
    try:
            os.mkdir(rainpath)
    except OSError as err:
            print("OS error: {0}".format(err))
    try:
        #try to get the rain data from a pickle file saved earlier 
        f = open(rainpath+'/Rainfall_data'+'.pkl', 'rb')
        rain = pickle.load(f)
        Studysite_rain = rain['Studysite_rain']
        print('loaded rainfall grids from file:'+rainpath+'Rainfall_data.pkl')
        f.close()
    except:
        #Grab bom_rainfall_grids from the datacube
        print('loaded bom rainfall grids from datacube')
        Studysite_rain = dc.load(product = 'bom_rainfall_grids', **query)
        #make a dictionary of the data we want to save
        vars2pickle = {'Studysite_rain':Studysite_rain}
        f = open(rainpath+'/Rainfall_data'+'.pkl', 'wb')
        pickle.dump(vars2pickle,f) 
        print('saved rainfall data to file')
        #pickle.dump(vars2pickle,f,protocol = 2, fix_imports = True) #maintain compatibility with python 2
        f.close()   

    #Mask the data with the polygon. Invert = True means you want the contents of the mask
    #I've added 'all touched = True, otherwise we get nothing in the output.
    mask = geometry_mask([geom], Studysite_rain.geobox, all_touched=True,invert=True)
    Studysite_rain_masked = Studysite_rain.where(mask)

    #resample xarray Dataset Studysite_rain by Annual'AS' to get yearly avg with year starting in october
    #Note that the resampling we did means that each year is labelled according to its first day  
    year_avg = Studysite_rain_masked.resample('AS-OCT', dim='time', how='mean', keep_attrs=True)

    # Create a spatial average
    year_avg_sp = year_avg.mean(dim = ('latitude', 'longitude'))

    # Find the 95th percentile in rainfall
    threshold95 = year_avg_sp.reduce(np.percentile, dim = 'time', q = 95)

    # Find the 5th percentile in rainfall (least)
    threshold5 = year_avg_sp.reduce(np.percentile, dim = 'time', q = 5)
    #print('5th  q: ',threshold5.rainfall.values,'\n'+'95th q: ',threshold95.rainfall.values )

    #work out which of the years have rainfall greater than 95th and less than 5th percentile
    wet_yrs = year_avg_sp.where(year_avg_sp.rainfall>=threshold95).dropna(dim = 'time')
    dry_yrs = year_avg_sp.where(year_avg_sp.rainfall<=threshold5).dropna(dim = 'time')

    #turn into numpy datetimes for later timeslicing
    wet_dt=np.array(wet_yrs.time.values,dtype = 'datetime64[Y]')
    dry_dt=np.array(dry_yrs.time.values,dtype = 'datetime64[Y]')

    #print out our wet and dry years
    print('wet years begin: ', wet_dt)
    print('dry years begin: ', dry_dt)

    #type(wet_dt[0])
    print(i)
    print('driest year is :',big_poly.DN[i])

    #now add the wet and dry years back into the geodataframe
    big_poly.set_value(i,'WY1',str(wet_dt[0]))
    big_poly.set_value(i,'WY2',str(wet_dt[1]))
    big_poly.set_value(i,'DY1',str(dry_dt[0]))
    big_poly.set_value(i,'DY2',str(dry_dt[1]))
# Out:
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_0/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_0/Rainfall_data.pkl
# wet years begin:  ['1990' '2010']
# dry years begin:  ['1992' '1993']
# 0
# driest year is : 1993
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_1/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_1/Rainfall_data.pkl
# wet years begin:  ['2008' '2010']
# dry years begin:  ['1986' '1993']
# 1
# driest year is : 1986
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_2/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_2/Rainfall_data.pkl
# wet years begin:  ['2008' '2010']
# dry years begin:  ['1986' '2002']
# 2
# driest year is : 1986
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_3/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_3/Rainfall_data.pkl
# wet years begin:  ['1999' '2010']
# dry years begin:  ['2002' '2013']
# 3
# driest year is : 2013
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_4/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_4/Rainfall_data.pkl
# wet years begin:  ['1990' '2008']
# dry years begin:  ['1993' '2012']
# 4
# driest year is : 1993
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_5/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_5/Rainfall_data.pkl
# wet years begin:  ['1999' '2010']
# dry years begin:  ['2002' '2013']
# 5
# driest year is : 2002
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_6/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_6/Rainfall_data.pkl
# wet years begin:  ['2008' '2010']
# dry years begin:  ['1992' '1993']
# 6
# driest year is : 1993
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_7/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_7/Rainfall_data.pkl
# wet years begin:  ['2008' '2010']
# dry years begin:  ['1986' '2013']
# 7
# driest year is : 2013
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_8/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_8/Rainfall_data.pkl
# wet years begin:  ['2008' '2010']
# dry years begin:  ['1992' '1993']
# 8
# driest year is : 1992
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_9/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_9/Rainfall_data.pkl
# wet years begin:  ['2008' '2010']
# dry years begin:  ['1986' '1992']
# 9
# driest year is : 1986
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_10/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_10/Rainfall_data.pkl
# wet years begin:  ['2008' '2010']
# dry years begin:  ['1992' '1993']
# 10
# driest year is : 1993
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_11/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_11/Rainfall_data.pkl
# wet years begin:  ['1990' '2008']
# dry years begin:  ['1986' '2013']
# 11
# driest year is : 2013
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_12/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_12/Rainfall_data.pkl
# wet years begin:  ['2008' '2010']
# dry years begin:  ['1992' '1994']
# 12
# driest year is : 1994
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_13/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_13/Rainfall_data.pkl
# wet years begin:  ['2008' '2010']
# dry years begin:  ['1992' '1995']
# 13
# driest year is : 1995
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_14/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_14/Rainfall_data.pkl
# wet years begin:  ['1990' '2010']
# dry years begin:  ['1986' '2002']
# 14
# driest year is : 1986
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_15/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_15/Rainfall_data.pkl
# wet years begin:  ['1990' '2007']
# dry years begin:  ['1986' '1992']
# 15
# driest year is : 1986
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_16/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_16/Rainfall_data.pkl
# wet years begin:  ['2010' '2011']
# dry years begin:  ['1992' '2013']
# 16
# driest year is : 2013
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_17/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_17/Rainfall_data.pkl
# wet years begin:  ['2007' '2010']
# dry years begin:  ['1991' '1992']
# 17
# driest year is : 1991
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_18/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_18/Rainfall_data.pkl
# wet years begin:  ['1990' '2010']
# dry years begin:  ['1991' '2013']
# 18
# driest year is : 2013
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_19/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_19/Rainfall_data.pkl
# wet years begin:  ['2009' '2011']
# dry years begin:  ['2002' '2012']
# 19
# driest year is : 2012
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_20/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_20/Rainfall_data.pkl
# wet years begin:  ['2009' '2011']
# dry years begin:  ['2002' '2012']
# 20
# driest year is : 2002
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_21/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_21/Rainfall_data.pkl
# wet years begin:  ['2007' '2010']
# dry years begin:  ['1991' '1992']
# 21
# driest year is : 1991
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_22/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_22/Rainfall_data.pkl
# wet years begin:  ['2007' '2010']
# dry years begin:  ['1991' '1993']
# 22
# driest year is : 1993
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_23/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_23/Rainfall_data.pkl
# wet years begin:  ['2009' '2011']
# dry years begin:  ['1992' '1994']
# 23
# driest year is : 1994
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_24/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_24/Rainfall_data.pkl
# wet years begin:  ['2009' '2011']
# dry years begin:  ['1992' '2012']
# 24
# driest year is : 2012
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_25/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_25/Rainfall_data.pkl
# wet years begin:  ['2007' '2010']
# dry years begin:  ['1992' '2001']
# 25
# driest year is : 2001
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_26/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_26/Rainfall_data.pkl
# wet years begin:  ['2007' '2009']
# dry years begin:  ['2002' '2013']
# 26
# driest year is : 2013
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_27/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_27/Rainfall_data.pkl
# wet years begin:  ['2007' '2010']
# dry years begin:  ['1991' '1992']
# 27
# driest year is : 1992
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_28/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_28/Rainfall_data.pkl
# wet years begin:  ['1989' '2009']
# dry years begin:  ['2002' '2012']
# 28
# driest year is : 2002
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_29/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_29/Rainfall_data.pkl
# wet years begin:  ['2007' '2009']
# dry years begin:  ['2002' '2012']
# 29
# driest year is : 2012
# OS error: [Errno 17] File exists: '/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_30/'
# loaded rainfall grids from file:/g/data/r78/rjd547/groundwater_activities/Rain/burdekin_polygons_0_5_deg_30/Rainfall_data.pkl
# wet years begin:  ['2007' '2009']
# dry years begin:  ['2002' '2012']
# 30
# driest year is : 2002

# %%
big_poly
# Out:
#       DN  Id                                           geometry   WY1   WY2  \
# 0   1993   1  POLYGON ((145 -18.1, 145.15 -18.1, 145.15 -18....  1990  2010
# 1   1986   2  POLYGON ((144.85 -18.15, 145 -18.15, 145 -18.2...  2008  2010
# 2   1986   3  POLYGON ((145.15 -18.6, 145.2 -18.6, 145.2 -18...  2008  2010
# 3   2013   4  POLYGON ((145.55 -18.35, 145.7 -18.35, 145.7 -...  1999  2010
# 4   1993   5  POLYGON ((144.55 -18.75, 144.75 -18.75, 144.75...  1990  2008
# 5   2002   6  POLYGON ((145.35 -18.3, 145.6 -18.3, 145.6 -18...  1999  2010
# 6   1993   7  POLYGON ((145.2 -18.9, 145.3 -18.9, 145.3 -19,...  2008  2010
# 7   2013   8  POLYGON ((145.5 -18.9, 145.6 -18.9, 145.6 -18....  2008  2010
# 8   1992   9  POLYGON ((144.95 -18.3, 145.05 -18.3, 145.05 -...  2008  2010
# 9   1986  10  POLYGON ((145.1 -19.4, 145.45 -19.4, 145.45 -1...  2008  2010
# 10  1993  11  POLYGON ((144.6 -19.3, 144.7 -19.3, 144.7 -19....  2008  2010
# 11  2013  12  POLYGON ((147.4 -19.5, 147.6 -19.5, 147.6 -19....  1990  2008
# 12  1994  13  POLYGON ((145.7 -19.1, 145.9 -19.1, 145.9 -19....  2008  2010
# 13  1995  14  POLYGON ((145.5 -19.9, 145.7 -19.9, 145.7 -19....  2008  2010
# 14  1986  15  POLYGON ((147.6 -19.6, 147.65 -19.6, 147.65 -1...  1990  2010
# 15  1986  16  POLYGON ((147.25 -20.5, 147.3 -20.5, 147.3 -20...  1990  2007
# 16  2013  17  POLYGON ((144.45 -19.4, 144.5 -19.4, 144.5 -19...  2010  2011
# 17  1991  18  POLYGON ((145.8 -20.6, 146 -20.6, 146 -20.65, ...  2007  2010
# 18  2013  19  POLYGON ((147.95 -20.35, 148.05 -20.35, 148.05...  1990  2010
# 19  2012  20  POLYGON ((145.65 -21.8, 145.85 -21.8, 145.85 -...  2009  2011
# 20  2002  21  POLYGON ((146 -21.8, 146.05 -21.8, 146.05 -21....  2009  2011
# 21  1991  22  POLYGON ((146.75 -22.05, 146.85 -22.05, 146.85...  2007  2010
# 22  1993  23  POLYGON ((147.2 -21.85, 147.25 -21.85, 147.25 ...  2007  2010
# 23  1994  24  POLYGON ((146.55 -22, 146.65 -22, 146.65 -22.0...  2009  2011
# 24  2012  25  POLYGON ((146.1 -21.8, 146.15 -21.8, 146.15 -2...  2009  2011
# 25  2001  26  POLYGON ((147.45 -22.6, 147.65 -22.6, 147.65 -...  2007  2010
# 26  2013  27  POLYGON ((147.25 -22.85, 147.4 -22.85, 147.4 -...  2007  2009
# 27  1992  28  POLYGON ((145.95 -19.7, 146.1 -19.7, 146.1 -19...  2007  2010
# 28  2002  29  POLYGON ((146.2 -23.35, 146.4 -23.35, 146.4 -2...  1989  2009
# 29  2012  30  POLYGON ((146.9 -22.95, 146.95 -22.95, 146.95 ...  2007  2009
# 30  2002  31  POLYGON ((146.85 -23.15, 147.05 -23.15, 147.05...  2007  2009
#
#      DY1   DY2
# 0   1992  1993
# 1   1986  1993
# 2   1986  2002
# 3   2002  2013
# 4   1993  2012
# 5   2002  2013
# 6   1992  1993
# 7   1986  2013
# 8   1992  1993
# 9   1986  1992
# 10  1992  1993
# 11  1986  2013
# 12  1992  1994
# 13  1992  1995
# 14  1986  2002
# 15  1986  1992
# 16  1992  2013
# 17  1991  1992
# 18  1991  2013
# 19  2002  2012
# 20  2002  2012
# 21  1991  1992
# 22  1991  1993
# 23  1992  1994
# 24  1992  2012
# 25  1992  2001
# 26  2002  2013
# 27  1991  1992
# 28  2002  2012
# 29  2002  2012
# 30  2002  2012

# %%
# big_poly.to_file('/g/data/r78/rjd547/groundwater_activities/Rain/Burdekin_Shapes/BurWetDry1.shp', 
#                  driver='ESRI Shapefile')

# %%
# big_poly.to_csv('/g/data/r78/rjd547/groundwater_activities/Rain/Burdekin_Shapes/BurWetDry.csv')
